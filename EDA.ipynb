# %%
import numpy as np
import pandas as pd
import os
from glob import glob 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = '../input/data/train/images'
os.listdir(data_path)[:3]
# Out:
# ['000515_female_Asian_50',
#  '000771_female_Asian_58',
#  '._000274_female_Asian_54']

# %%
train_df = pd.read_csv('../input/data/train/train.csv')
train_df.head(3)
# Out:
#        id  gender   race  age                    path
# 0  000001  female  Asian   45  000001_female_Asian_45
# 1  000002  female  Asian   52  000002_female_Asian_52
# 2  000004    male  Asian   54    000004_male_Asian_54

# %%
sns.countplot(x='gender', data=train_df)

# %%
fig, ax = plt.subplots(figsize=(12, 7))

sns.histplot(x='age', data= train_df, ax=ax,
             hue='gender', binwidth=10,
             multiple='dodge', # layer, dodge, stack, fill
            )

plt.show()

# %% [markdown]
# - 여성이 많음
# - 20, 40, 50 대에서 여성과 남성의 비율에 차이가 두드러짐
